# %%
from wrangle import Wrangle
from prepare import Prepare
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train, val, test = Wrangle().wrangle_zillow()
train.head()
# Out:
#        bedrooms  bathrooms  square_feet  home_tax_value  year_built    fips  \
# 24082       3.0        2.0       1040.0        315000.0      1971.0  6037.0
# 9432        4.0        1.0       1354.0         51513.0      1947.0  6037.0
# 50142       3.0        1.0       1180.0         64709.0      1949.0  6037.0
# 38310       3.0        2.0       1922.0        218663.0      1952.0  6037.0
# 7652        4.0        4.0       3710.0       1700000.0      1987.0  6037.0
#
#             county
# 24082  Los Angeles
# 9432   Los Angeles
# 50142  Los Angeles
# 38310  Los Angeles
# 7652   Los Angeles

# %%
train["fips"].value_counts()
# Out:
# 6037.0    20937
# 6059.0     8796
# 6111.0     2710
# Name: fips, dtype: int64

# %%
train["county"].value_counts()
# Out:
# Los Angeles    20937
# Orange          8796
# Ventura         2710
# Name: county, dtype: int64

# %%
sns.scatterplot(x="square_feet", y="home_tax_value", data=train);

# %%
sns.barplot(x="bedrooms", y="home_tax_value", data=train);

# %%
sns.barplot(x="bathrooms", y="home_tax_value", data=train);

# %%
sns.barplot(x="county", y="home_tax_value", ci=False, data=train);

# %%
sns.lineplot(x="year_built", y="home_tax_value",  hue="county", ci=False,  data=train);

# %%
new_even = train[(train["bedrooms"] % 2 == 0) & (train["bathrooms"] % 2 == 0)]
new_even
# Out:
#        bedrooms  bathrooms  square_feet  home_tax_value  year_built    fips
# 7652        4.0        4.0       3710.0       1700000.0      1987.0  6037.0
# 736         4.0        2.0       1475.0        464984.0      1955.0  6059.0
# 19446       4.0        2.0       2102.0        236324.0      1965.0  6037.0
# 5226        2.0        2.0        983.0        375000.0      1975.0  6059.0
# 34457       4.0        2.0       1484.0        352248.0      1955.0  6037.0
# ...         ...        ...          ...             ...         ...     ...
# 48170       4.0        2.0       1908.0         79551.0      1960.0  6037.0
# 12005       4.0        4.0       3044.0       1218299.0      1938.0  6037.0
# 30924       2.0        2.0       1836.0         88646.0      1950.0  6037.0
# 11761       4.0        2.0       1500.0        404892.0      1967.0  6037.0
# 28075       2.0        2.0       1248.0        468872.0      1936.0  6037.0
#
# [5892 rows x 6 columns]

# %%
new_odd = train[(train["bedrooms"] % 2 == 1) & (train["bathrooms"] % 2 == 1)]
new_odd
# Out:
#        bedrooms  bathrooms  square_feet  home_tax_value  year_built    fips
# 50142       3.0        1.0       1180.0         64709.0      1949.0  6037.0
# 49024       3.0        3.0       1674.0        342743.0      1976.0  6111.0
# 465         1.0        1.0        520.0         32640.0      1922.0  6037.0
# 18452       3.0        1.0        924.0        284269.0      1956.0  6037.0
# 30677       5.0        5.0       3554.0        996781.0      2007.0  6059.0
# ...         ...        ...          ...             ...         ...     ...
# 28077       3.0        5.0       3301.0       2306002.0      1937.0  6037.0
# 34340       3.0        3.0       1840.0        630369.0      1967.0  6037.0
# 8155        3.0        1.0       1248.0        246455.0      1908.0  6037.0
# 2316        3.0        1.0       1052.0        456240.0      1953.0  6111.0
# 48101       3.0        1.0       1019.0         45866.0      1949.0  6037.0
#
# [5911 rows x 6 columns]

# %%
sns.barplot(x="bedrooms", y="home_tax_value", data=new_even);

# %%
sns.barplot(x="bedrooms", y="home_tax_value", data=new_odd);

# %%
sns.barplot(x="bathrooms", y="home_tax_value", data=new_even);

# %%
sns.barplot(x="bathrooms", y="home_tax_value", data=new_odd);

# %%
sns.histplot(x="home_tax_value", data=new_odd);

# %%
sns.histplot(x="home_tax_value", data=new_even);
