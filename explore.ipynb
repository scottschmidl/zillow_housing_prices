# %%
from wrangle import Wrangle
from prepare import Prepare
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train, val, test = Wrangle().wrangle_zillow()
train.head()
# Out:
# zillow.csv not found. Connecting to MySQL database and reading table to dataframe.
# Connected successfully
# Table saved to zillow.csv
# (52442, 7)
#        bedroom_count  bathroom_count  calculated_finished_sq_ft  \
# 24082            3.0             2.0                     1040.0
# 9432             4.0             1.0                     1354.0
# 50142            3.0             1.0                     1180.0
# 38310            3.0             2.0                     1922.0
# 7652             4.0             4.0                     3710.0
#
#        tax_value_dollar_count  year_built
# 24082                315000.0      1971.0
# 9432                  51513.0      1947.0
# 50142                 64709.0      1949.0
# 38310                218663.0      1952.0
# 7652                1700000.0      1987.0

# %%
sns.barplot(x="bedroom_count", y="tax_value_dollar_count", data=train);

# %%
sns.barplot(x="bathroom_count", y="tax_value_dollar_count", data=train);

# %%
sns.scatterplot(x="calculated_finished_sq_ft", y="tax_value_dollar_count", data=train);

# %%
sns.lineplot(x="year_built", y="tax_value_dollar_count", data=train);
